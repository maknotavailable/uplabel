# %% [markdown]
# # UpLabel - Visualize Progress

# %%
import matplotlib.pyplot as plt

import sys 
sys.path.append('../code')
import visualize as vi

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
project_id = 'ex1'

# %%
progress = vi.Reporting(project_id)

# %%
progress.get_progress()
# Out:
#    complexity  data_length  iteration  labeled_length  labels  performance
# 0    0.722222        14458          0             100       5     0.722222
# 1    0.813173        14459          1             700       5     0.813173
# 2    0.686395        14468          2            1299       5     0.686395

# %%
progress.plot('complexity')

# %%
# progress.plot('performance')

# %%
progress.plot('labeled_length')
